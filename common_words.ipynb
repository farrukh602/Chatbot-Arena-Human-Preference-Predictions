# %%
import pandas as pd

# %%
def split_text(text):
    return text.split()

# %%
train = pd.read_pickle('train.pkl')

# %%
train['temp_list'] = train['prompt'].apply(split_text)

# %%
train
# Out:
#                id             model_a              model_b  \
# 0           30192  gpt-4-1106-preview           gpt-4-0613
# 1           53567           koala-13b           gpt-4-0613
# 2           65089  gpt-3.5-turbo-0613       mistral-medium
# 3           96401    llama-2-13b-chat  mistral-7b-instruct
# 4          198779           koala-13b   gpt-3.5-turbo-0314
# ...           ...                 ...                  ...
# 57472  4294656694          gpt-4-0613             claude-1
# 57473  4294692063          claude-2.0     llama-2-13b-chat
# 57474  4294710549            claude-1           alpaca-13b
# 57475  4294899228              palm-2       tulu-2-dpo-70b
# 57476  4294947231  gemini-pro-dev-api   gpt-4-1106-preview
#
#                                                   prompt  \
# 0      morally right try certain percentage females m...
# 1      difference marriage license marriage certifica...
# 2           explain function calling would call function
# ...

# %%
train = {
    'temp_list': [[1, 2, 3], [4, 5], [6, 7, 8, 9]]
}
from collections import Count
fl = Count([item for sublist in train['temp_list'] for item in sublist])
fl
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 4
#       1 train = {
#       2     'temp_list': [[1, 2, 3], [4, 5], [6, 7, 8, 9]]
#       3 }
# ----> 4 from collections import Count
#       5 fl = Count([item for sublist in train['temp_list'] for item in sublist])
#       6 fl
#
# ImportError: cannot import name 'Count' from 'collections' (C:\Users\Pakistan\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\collections\__init__.py)

# %%
import collections
dir(collections)
# Out:
# ['ChainMap',
#  'Counter',
#  'OrderedDict',
#  'UserDict',
#  'UserList',
#  'UserString',
#  '_Link',
#  '_OrderedDictItemsView',
#  '_OrderedDictKeysView',
#  '_OrderedDictValuesView',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_chain',
#  '_collections_abc',
#  '_count_elements',
#  '_deque_iterator',
#  '_eq',
#  '_iskeyword',
#  '_itemgetter',
#  '_proxy',
#  '_recursive_repr',
#  '_repeat',
#  '_starmap',
#  '_sys',
#  '_tuplegetter',
#  'abc',
#  'defaultdict',
#  'deque',
#  'namedtuple']
